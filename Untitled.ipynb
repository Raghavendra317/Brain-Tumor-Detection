# %%
import zipfile
import os

# Define the file name (Replace with your actual file name if different)
zip_file = "archive.zip"

# Extract the zip file
with zipfile.ZipFile(zip_file, 'r') as zip_ref:
    zip_ref.extractall("brain_tumor_dataset")  # Extract to a new folder

print("Extraction complete!")
# Out:
# Extraction complete!

# %%
# List the files in the extracted dataset directory
dataset_path = "brain_tumor_dataset"
print(os.listdir(dataset_path))
# Out:
# ['Testing', 'Training']

# %%
# Check class categories inside Training folder
train_path = os.path.join(dataset_path, "Training")
print("Categories in Training folder:", os.listdir(train_path))

# Check class categories inside Testing folder
test_path = os.path.join(dataset_path, "Testing")
print("Categories in Testing folder:", os.listdir(test_path))
# Out:
# Categories in Training folder: ['glioma', 'meningioma', 'notumor', 'pituitary']
# Categories in Testing folder: ['glioma', 'meningioma', 'notumor', 'pituitary']

# %%
import matplotlib.pyplot as plt
import cv2

# Function to display sample images
def display_images(folder, label, num_images=4):
    images = os.listdir(folder)[:num_images]
    
    plt.figure(figsize=(12, 5))
    for i, img_name in enumerate(images):
        img_path = os.path.join(folder, img_name)
        img = cv2.imread(img_path)  # Read the image
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)  # Convert from BGR to RGB
        
        plt.subplot(1, num_images, i+1)
        plt.imshow(img)
        plt.axis("off")
        plt.title(label)
    
    plt.show()

# Display images for all 4 categories
for category in ['glioma', 'meningioma', 'notumor', 'pituitary']:
    category_path = os.path.join(train_path, category)
    display_images(category_path, category)

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import os

# %%
# Image size & batch size
IMAGE_SIZE = (150, 150)
BATCH_SIZE = 32

# Dataset paths
train_dir = os.path.join(dataset_path, "Training")
test_dir = os.path.join(dataset_path, "Testing")

# %%
# Data Augmentation & Rescaling for Training Data
train_datagen = ImageDataGenerator(
    rescale=1./255,        # Normalize pixel values
    rotation_range=20,     # Random rotation
    width_shift_range=0.2, # Horizontal shift
    height_shift_range=0.2,# Vertical shift
    shear_range=0.2,       # Shear transformation
    zoom_range=0.2,        # Random zoom
    horizontal_flip=True,  # Flip images
    validation_split=0.2   # 20% data for validation
)

# Load Training Data
train_data = train_datagen.flow_from_directory(
    train_dir,
    target_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    class_mode="categorical",  # Multi-class classification
    subset="training"
)

# Load Validation Data
val_data = train_datagen.flow_from_directory(
    train_dir,
    target_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    class_mode="categorical",
    subset="validation"
)

# Rescale Testing Data (No Augmentation)
test_datagen = ImageDataGenerator(rescale=1./255)

test_data = test_datagen.flow_from_directory(
    test_dir,
    target_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    class_mode="categorical"
)
# Out:
# Found 4571 images belonging to 4 classes.
# Found 1141 images belonging to 4 classes.
# Found 1311 images belonging to 4 classes.

# %%
# Check class labels
print("Class Labels:", train_data.class_indices)

# Check sample batch shape
sample_batch, sample_labels = next(train_data)
print("Batch Shape:", sample_batch.shape)
print("Label Shape:", sample_labels.shape)
# Out:
# Class Labels: {'glioma': 0, 'meningioma': 1, 'notumor': 2, 'pituitary': 3}
# Batch Shape: (32, 150, 150, 3)
# Label Shape: (32, 4)

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization

# %%
# Define CNN Model
model = Sequential([
    # Convolutional Layer 1
    Conv2D(32, (3,3), activation='relu', input_shape=(150,150,3)),
    MaxPooling2D(2,2),
    
    # Convolutional Layer 2
    Conv2D(64, (3,3), activation='relu'),
    MaxPooling2D(2,2),
    
    # Convolutional Layer 3
    Conv2D(128, (3,3), activation='relu'),
    MaxPooling2D(2,2),

    # Flatten Layer
    Flatten(),
    
    # Fully Connected Layer
    Dense(128, activation='relu'),
    Dropout(0.5),  # Dropout to reduce overfitting
    
    # Output Layer (4 classes)
    Dense(4, activation='softmax')
])
# Out:
# C:\Users\USER\anaconda3\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(
    loss='categorical_crossentropy',
    optimizer='adam',
    metrics=['accuracy']
)

# Model Summary
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 148, 148, 32)        │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 74, 74, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 72, 72, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 36, 36, 64)          │               0 │
# ...

# %%
# Set the number of epochs
EPOCHS = 10

# Train the model
history = model.fit(
    train_data,
    validation_data=val_data,
    epochs=EPOCHS
)
# Out:
# C:\Users\USER\anaconda3\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/10
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 139s 952ms/step - accuracy: 0.4343 - loss: 1.1610 - val_accuracy: 0.5890 - val_loss: 1.0487
# Epoch 2/10
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 90s 629ms/step - accuracy: 0.6314 - loss: 0.8349 - val_accuracy: 0.6687 - val_loss: 0.9374
# Epoch 3/10
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 90s 632ms/step - accuracy: 0.6854 - loss: 0.7452 - val_accuracy: 0.6933 - val_loss: 0.9217
# Epoch 4/10
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 90s 629ms/step - accuracy: 0.7252 - loss: 0.6789 - val_accuracy: 0.6871 - val_loss: 0.8248
# Epoch 5/10
# ...

# %%
import matplotlib.pyplot as plt

# Plot Accuracy
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.title('Model Accuracy')
plt.show()

# Plot Loss
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.title('Model Loss')
plt.show()

# %%
# Evaluate the model
test_loss, test_acc = model.evaluate(test_data)

print(f"Test Accuracy: {test_acc:.4f}")
print(f"Test Loss: {test_loss:.4f}")
# Out:
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 13s 313ms/step - accuracy: 0.6057 - loss: 1.3242
# Test Accuracy: 0.6201
# Test Loss: 1.3346

# %%
from sklearn.metrics import classification_report
import numpy as np

# Get predictions
y_pred = model.predict(test_data)
y_pred_classes = np.argmax(y_pred, axis=1)  # Convert probabilities to class labels

# Get true labels
y_true = test_data.classes

# Print classification report
class_labels = ['glioma', 'meningioma', 'notumor', 'pituitary']
print(classification_report(y_true, y_pred_classes, target_names=class_labels))
# Out:
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 5s 126ms/step
#               precision    recall  f1-score   support
#
#       glioma       0.17      0.08      0.11       300
#   meningioma       0.28      0.13      0.18       306
#      notumor       0.29      0.51      0.37       405
#    pituitary       0.23      0.24      0.24       300
#
#     accuracy                           0.26      1311
#    macro avg       0.24      0.24      0.22      1311
# weighted avg       0.25      0.26      0.23      1311

# %%
import seaborn as sns
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt

# Compute confusion matrix
cm = confusion_matrix(y_true, y_pred_classes)

# Plot confusion matrix
plt.figure(figsize=(6,6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_labels, yticklabels=class_labels)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# %%
import os
import tensorflow as tf

# Create the "model" directory inside the current working directory
model_dir = os.path.join(os.getcwd(), "model")
os.makedirs(model_dir, exist_ok=True)  # Create if it doesn't exist

# Define model save path
model_path = os.path.join(model_dir, "brain_tumor_model.keras")

# Save the trained model
model.save(model_path)

print(f"✅ Model saved successfully at: {model_path}")
# Out:
# ✅ Model saved successfully at: C:\Users\USER\Brain\model\brain_tumor_model.keras

# %%
import tensorflow as tf

# Load the saved model
model_path = "model/brain_tumor_model.keras"
loaded_model = tf.keras.models.load_model(model_path)

# Print model summary to verify successful loading
loaded_model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 148, 148, 32)        │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 74, 74, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 72, 72, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 36, 36, 64)          │               0 │
# ...
